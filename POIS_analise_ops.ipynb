# %%
import pandas as pd
import geopandas as gpd
import folium
import geopy
from geopy.distance import geodesic
from shapely.geometry import Point
import branca.colormap as cm
from ipywidgets import interact_manual, widgets, VBox, HBox
import ipywidgets as widgets
from sklearn.preprocessing import MinMaxScaler
import zipfile
import os
import fiona
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
pois_linestrings= gpd.read_file("pois_linestrings.shp")
pois_points= gpd.read_file("pois_points.shp")
pois_poligonos= gpd.read_file("pois_poligonos.shp")

# %%
# pois_linestrings
pois_poligonos[pois_poligonos['fclass']=='police']
# Out:
#            osm_id  fclass                                               name  \
# 294      93249276  police                                               None
# 321     104291524  police  Polícia Militar - Comando de Policiamento da C...
# 434     121546222  police                              99º DP - Campo Grande
# 912       2070362  police                     Academia de Polícia - Campus I
# 1007    155852282  police            75º Distrito Policial (Jardim Arpoador)
# 1008    155859382  police                         Polícia Militar Rodoviária
# 1076    158967598  police                    16º Batalhão da Polícia Militar
# 1077    158967600  police                              93º Distrito Policial
# 1078    159112172  police                              35º Distrito Policial
# 1097    160689310  police  Polícia Federal Superintendência Regional de S...
# 1165    168760836  police  16° Distrito Policial e 2° Delegacia de Defesa...
# 1417    202982310  police     Núcleo de Perícias Criminalísticas - EPC NORTE
# 1452    210813174  police                                             70ª DP
# 1568    230965360  police                                 56º DP Vila Alpina
# 1588    231110978  police                 Rondas Ostensivas Tobias de Aguiar
# 1895    246945313  police                              44º Distrito Policial
# 2258    267489397  police                           68º Delegacia de Policia
# 2290    269308907  police                                  Polícia Ambiental
# 2385    279654373  police  Polícia Militar Rodoviária - Base SP-150/1 - k...
# 2668    297828955  police                                               None
# 2683      3963422  police     Superintendência de Polícia Técnico-Científica
# 2778    304259560  police                   1º Batalhão de Policia Ambiental
# 2785    306773964  police                                       Guarda Civil
# 2882    318719657  police                                               DEIC
# 3166    329132164  police                                             92º DP
# 3307    340370000  police          90ª Delegacia de Policia e Batalhao da PM
# 3625    381602130  police                              83° Distrito Policial
# 3673    385056284  police                51 Delegacia de Polícia Rio Pequeno
# 3784    391656621  police                        Polícia Militar de Trânsito
# 3811    393469143  police                      Posto da Guarda Universitária
# 3876    402888742  police                      Policia Militar 19ª BPM 3ªCIA
# 3909    404829771  police                                             3ª Cia
# 4125    414735571  police                              78º Distrito Policial
# 4193    416702815  police                        Polícia Rodoviária Estadual
# 4352    420089136  police                                               None
# 4442    421146497  police    Departamento de Polícia de Proteção à Cidadania
# 4462    421297104  police                            3ª Delegacia de Polícia
# 4469    421301260  police                         Guarda Civil Metropolitana
# 4475    421301482  police              Comando da Guarda Civil Metropolitana
# 4499    421359510  police      Base Comunitária de Segurança POLÍCIA MILITAR
# 5253    437322924  police             Policia Cívil - Divisão de Transportes
# 5823      6679011  police                                             14º DP
# 6108    453404727  police                         Guarda Civil Metropolitana
# 6218    456827088  police                              Policia Militar de SP
# 6239    459349208  police                              19º Distrito Policial
# 6496      6855650  police                              12º Distrito Policial
# 6549    464389326  police                           Posto da Polícia Militar
# 6615    466020545  police                                               None
# 6636    466030740  police                                    Policia Militar
# 6650    466130916  police              53º Distrito Policial Parque do Carmo
# 7130    485425303  police         Delegacia de Polícia Civil do 34º distrito
# 7258    489956893  police  66º Distrito Policial / 8ª DDM - Delegacia de ...
# 7359    494216441  police                                     3ª Cia 43º BPM
# 7529    503281083  police          52º Distrito Policial do Parque São Jorge
# 9140    521405638  police         Polícia Militar. 3ª Companhia do 12º BPM/M
# 9378    541792787  police                                               None
# 10248   565130769  police                3ª Companhia de Radio Patrulhamento
# 10530   603098267  police                    22º Batalhão da Polícia Militar
# 10828   618152351  police                                   Base Comunitaria
# 11136   618656794  police                         Guarda Civil Metropolitana
# 11139   618658519  police                    50º Batalhão de Polícia Militar
# 11140   618659414  police  25° DP - Parelheiros - Polícia Civil - Distrit...
# 11141   618659452  police                         Guarda Civil Metropolitana
# 11178   618871332  police                Base Comunitária da Polícia Militar
# 11189   618936020  police  85° Distrito Policial - Jardim Myrna - Polícia...
# 11432     8556208  police  48º DP - Cidade Dutra - Polícia Civil - Distri...
# 11465   619047105  police                         Guarda Civil Metropolitana
# 11469   619048267  police                                    Polícia Militar
# 11509   619058309  police             Polícia Civil - 101º Distrito Policial
# 11525   619083802  police                                CPA M10 / 27º BPM/M
# 11529     8556505  police  50º Batalhão de Polícia Militar Metropolitano ...
# 11560   619304793  police  102° DP - Socorro - Polícia Civil - Distrito P...
# 11943   619316731  police                         Guarda Civil Metropolitana
# 12382   619917402  police                         Guarda Civil Metropolitana
# 12785   621035361  police                                    Policia Militar
# 12826   621910647  police                                              74 DP
# 12844   622212416  police                                               None
# 12863   622597015  police                        28º BPM/M Cidade Tiradentes
# 13142   641993303  police                        5º Batalhão Policia militar
# 13151   645706639  police                                               None
# 13200   660992328  police            Regimento de Polícia Montada 9 de Julho
# 13325   677510221  police                                Academia de Polícia
# 13394   681291699  police                         Guarda Civil Metropolitana
# 13632   684050297  police                             98º DP - Jardim Miriam
# 13702   686755661  police                             23 ° Distrito policial
# 14048   699476131  police                                               None
# 14110   701113318  police                                    Policia Militar
# 14131   703494803  police                                               None
# 14208   714037599  police                                Policia Comunitaria
# 14210   714037697  police                               9º Distrito Policial
# 14252   714049052  police          Corregedoria da Polícia Militar São Paulo
# 14267   714055565  police                                               None
# 14390   714657267  police               Superintendência da PRF em São Paulo
# 14967   718153383  police            Entrada da Base de escolta de São Paulo
# 15062   722533714  police  Polícia Militar Rodoviária - Base SP-348/1 - k...
# 15067   722807760  police  Polícia Militar Rodoviária - Comando do Polici...
# 15255   734819881  police                              39º Distrito Policial
# 15339   740415892  police                                               None
# 15784   776893693  police                                               None
# 15818   782262981  police                                   Base Comunitaria
# 15822   782530035  police                                               None
# 15899   795053493  police                   Base Comunitária Jardim Britânia
# 16014   815480248  police  Decap Departamento de Polícia Judiciaria da Cp...
# 16018   815710820  police                                            Demarco
# 16100   831047430  police                                               None
# 16235   856991364  police                                    Polícia Militar
# 16315   875551855  police             Policia Militar do Estado de São Paulo
# 16368   879444704  police                                    Base do Clipper
# 16382   879444722  police                                          18º BPM/M
# 16388   879444739  police             Polícia Militar do Estado de São Paulo
# 16561   908104760  police                    4ª Companhia da Polícia Militar
# 16692   930065590  police                                 Batalhão de Choque
# 16745   935186208  police                                    Policia Militar
# 16787   940447940  police                                    Policia Militar
# 16828   950146048  police                             Base Comunitaria da PM
# 16834   952473670  police          Centro de Treinamento da Guarda Municipal
# 16864   960182919  police                              40º Distrito Policial
# 16865   960182921  police                                      9º BPM 2ª Cia
# 17056    13297779  police                     9º Batalhão da Policia Militar
# 17071    13310015  police                               Batalhão de Transito
# 17076   992001210  police                                      2º B P Choque
# 17077   992001211  police                    Corregedoria da Polícia Militar
# 17081   992245191  police                                    Policia Militar
# 17087   992259154  police  COPOM   Centro de Operações da Polícia Militar...
# 17097    13335413  police                              29º Distrito policial
# 17136   996708241  police                                   Base Comunitaria
# 17194  1004135715  police                                               None
# 17208  1005963312  police                                     4ª cia 9º BPMM
# 17209  1005963313  police                                               None
# 17210  1005963314  police                              72º Distrito Policial
# 17285  1021174580  police                              81º Distrito Policial
# 17297  1023971173  police                                     1ª Cia 9º BPMM
# 17424  1038259627  police                                               None
# 17559  1050590222  police                                               None
# 17581  1051342507  police                                               None
# 17805  1057669446  police                               7º Distrito Policial
# 17806  1057669448  police                                     4ºBPM - 1ª CIA
# 17888  1061103333  police             Policia Militar do Estado de São Paulo
# 17889  1061103335  police       26º Distrito Policial da Cidade de São Paulo
# 18164  1072362494  police                             57º DP Parque da Mooca
# 18195  1072837258  police                                             18º DP
# 18382  1079070741  police                                               None
# 18429  1082119997  police                         Guarda Civil Metropolitana
# 18557    14534091  police                    8º Distrito Policial Belenzinho
# 18616    14558286  police                              20º Distrito Policial
# 19153  1126078106  police                               2º Distrito Policial
# 19181  1128222879  police                                               None
# 19182  1128222880  police                              10º Distrito Policial
# 19240  1135714074  police                              22º Distrito Policial
# 19241  1135714076  police                                 29ºBPM/M 2ª Cia PM
# 19269  1143725490  police                                            18º BPM
# 19279  1147199072  police                                               None
# 19280  1147199073  police                              41º Distrito Policial
# 19299  1149318352  police                                               DHPP
# 19341    15591251  police                              87º Distrito Policial
# 19397  1159139343  police                                             65º DP
# 19697  1174811016  police                              21º Distrito Policial
# 19698  1174811017  police                                               None
# 19775    15930637  police                              77º Distrito Policial
# 19782    15937563  police                              64º Distrito Policial
# 19787  1178588232  police                                               None
# 19821    15956308  police                                    Polícia Militar
# 19844    15976107  police                                                CMM
# 19884  1185566802  police                                             Denarc
# 19897  1189547642  police                         Polícia Técnico-Científica
# 20382  1218052239  police                            4ª Delegacia de Polícia
# 20675  1235732587  police                                              58ºDP
# 20682    11035161  police               Policia Militar 2 CIA do 49 Batalhão
# 20699  1238328384  police                              28º Distrito Policial
# 20751  1245530282  police                              13º Distrito Policial
# 20800  1251160314  police                                               None
# 20852  1260669922  police                                               None
# 20889  1268697901  police                              43º Distrito Policial
# 20890  1268697902  police                                             Conseg
# 20891  1268697903  police                                    3° CIA DO 22°BP
# 20941  1283742337  police                                              6º DP
# 21057  1296161401  police                                            CPA/M-9
# 21152  1307996968  police                                               None
# 21207    18012128  police                                             49º DP
#
#        numero_df  type                                           geometry
# 294            0  None  POLYGON ((-46.53407 -23.57987, -46.53356 -23.5...
# 321            0  None  POLYGON ((-46.63421 -23.53194, -46.63421 -23.5...
# 434            0  None  POLYGON ((-46.68728 -23.66211, -46.68720 -23.6...
# 912            0  None  POLYGON ((-46.71329 -23.56579, -46.71327 -23.5...
# 1007           0  None  POLYGON ((-46.79625 -23.59726, -46.79569 -23.5...
# 1008           0  None  POLYGON ((-46.79183 -23.58704, -46.79132 -23.5...
# 1076           0  None  POLYGON ((-46.74728 -23.55913, -46.74718 -23.5...
# 1077           0  None  POLYGON ((-46.74684 -23.55879, -46.74681 -23.5...
# 1078           0  None  POLYGON ((-46.64350 -23.63933, -46.64337 -23.6...
# 1097           0  None  POLYGON ((-46.70500 -23.51095, -46.70490 -23.5...
# 1165           0  None  POLYGON ((-46.63791 -23.60208, -46.63790 -23.6...
# 1417           0  None  POLYGON ((-46.64710 -23.50191, -46.64689 -23.5...
# 1452           0  None  POLYGON ((-46.53368 -23.59883, -46.53347 -23.5...
# 1568           0  None  POLYGON ((-46.56761 -23.59378, -46.56745 -23.5...
# 1588           0  None  POLYGON ((-46.63226 -23.53228, -46.63211 -23.5...
# 1895           0  None  POLYGON ((-46.41905 -23.54293, -46.41886 -23.5...
# 2258           0  None  POLYGON ((-46.39868 -23.53583, -46.39823 -23.5...
# 2290           0  None  POLYGON ((-46.52700 -23.49532, -46.52686 -23.4...
# 2385           0  None  POLYGON ((-46.59807 -23.62738, -46.59799 -23.6...
# 2668           0  None  POLYGON ((-46.64090 -23.64596, -46.64090 -23.6...
# 2683           0  None  POLYGON ((-46.71362 -23.56733, -46.71340 -23.5...
# 2778           0  None  POLYGON ((-46.66410 -23.50914, -46.66358 -23.5...
# 2785           0  None  POLYGON ((-46.65806 -23.58951, -46.65802 -23.5...
# 2882           0  None  POLYGON ((-46.62341 -23.51172, -46.62305 -23.5...
# 3166           0  None  POLYGON ((-46.75660 -23.66270, -46.75606 -23.6...
# 3307           0  None  POLYGON ((-46.57008 -23.50087, -46.56976 -23.5...
# 3625           0  None  POLYGON ((-46.61390 -23.65661, -46.61378 -23.6...
# 3673           0  None  POLYGON ((-46.72271 -23.57168, -46.72180 -23.5...
# 3784           0  None  POLYGON ((-46.62486 -23.53433, -46.62486 -23.5...
# 3811           0  None  POLYGON ((-46.72300 -23.56058, -46.72293 -23.5...
# 3876           0  None  POLYGON ((-46.53232 -23.58928, -46.53224 -23.5...
# 3909           0  None  POLYGON ((-46.72287 -23.57149, -46.72283 -23.5...
# 4125           0  None  POLYGON ((-46.66943 -23.56609, -46.66924 -23.5...
# 4193           0  None  POLYGON ((-46.77356 -23.44147, -46.77338 -23.4...
# 4352           0  None  POLYGON ((-46.64909 -23.54530, -46.64907 -23.5...
# 4442           0  None  POLYGON ((-46.64553 -23.53975, -46.64541 -23.5...
# 4462           0  None  POLYGON ((-46.63981 -23.53932, -46.63969 -23.5...
# 4469           0  None  POLYGON ((-46.63662 -23.53845, -46.63647 -23.5...
# 4475           0  None  POLYGON ((-46.63687 -23.53562, -46.63687 -23.5...
# 4499           0  None  POLYGON ((-46.64281 -23.53299, -46.64275 -23.5...
# 5253           0  None  POLYGON ((-46.61456 -23.60834, -46.61408 -23.6...
# 5823           0  None  POLYGON ((-46.69138 -23.56182, -46.69105 -23.5...
# 6108           0  None  POLYGON ((-46.63471 -23.52276, -46.63467 -23.5...
# 6218           0  None  POLYGON ((-46.43629 -23.54527, -46.43620 -23.5...
# 6239           0  None  POLYGON ((-46.58506 -23.51796, -46.58482 -23.5...
# 6496           0  None  POLYGON ((-46.61252 -23.52981, -46.61226 -23.5...
# 6549           0  None  POLYGON ((-46.60283 -23.52963, -46.60279 -23.5...
# 6615           0  None  POLYGON ((-46.59379 -23.54867, -46.59377 -23.5...
# 6636           0  None  POLYGON ((-46.60005 -23.55766, -46.60002 -23.5...
# 6650           0  None  POLYGON ((-46.46648 -23.56716, -46.46621 -23.5...
# 7130           0  None  POLYGON ((-46.72708 -23.58813, -46.72671 -23.5...
# 7258           0  None  POLYGON ((-46.49239 -23.55389, -46.49223 -23.5...
# 7359           0  None  POLYGON ((-46.62051 -23.47814, -46.62044 -23.4...
# 7529           0  None  POLYGON ((-46.56358 -23.53601, -46.56335 -23.5...
# 9140           0  None  POLYGON ((-46.66564 -23.59503, -46.66560 -23.5...
# 9378           0  None  POLYGON ((-46.69976 -23.72873, -46.69972 -23.7...
# 10248          0  None  POLYGON ((-46.44386 -23.53098, -46.44379 -23.5...
# 10530          0  None  POLYGON ((-46.68825 -23.68822, -46.68802 -23.6...
# 10828          0  None  POLYGON ((-46.63952 -23.50375, -46.63946 -23.5...
# 11136          0  None  POLYGON ((-46.73174 -23.80597, -46.73169 -23.8...
# 11139          0  None  POLYGON ((-46.73241 -23.82626, -46.73228 -23.8...
# 11140          0  None  POLYGON ((-46.73506 -23.82566, -46.73498 -23.8...
# 11141          0  None  POLYGON ((-46.73662 -23.81587, -46.73651 -23.8...
# 11178          0  None  POLYGON ((-46.68782 -23.74767, -46.68777 -23.7...
# 11189          0  None  POLYGON ((-46.69704 -23.77062, -46.69700 -23.7...
# 11432          0  None  POLYGON ((-46.69581 -23.71216, -46.69567 -23.7...
# 11465          0  None  POLYGON ((-46.70164 -23.72119, -46.70163 -23.7...
# 11469          0  None  POLYGON ((-46.69504 -23.72930, -46.69495 -23.7...
# 11509          0  None  POLYGON ((-46.70961 -23.72964, -46.70948 -23.7...
# 11525          0  None  POLYGON ((-46.70125 -23.70176, -46.70116 -23.7...
# 11529          0  None  POLYGON ((-46.70928 -23.74169, -46.70909 -23.7...
# 11560          0  None  POLYGON ((-46.71216 -23.67623, -46.71211 -23.6...
# 11943          0  None  POLYGON ((-46.71550 -23.68791, -46.71539 -23.6...
# 12382          0  None  POLYGON ((-46.70034 -23.65455, -46.69971 -23.6...
# 12785          0  None  POLYGON ((-46.57359 -23.48416, -46.57358 -23.4...
# 12826          0  None  POLYGON ((-46.71697 -23.44554, -46.71682 -23.4...
# 12844          0  None  POLYGON ((-46.41037 -23.48756, -46.41036 -23.4...
# 12863          0  None  POLYGON ((-46.40922 -23.58413, -46.40913 -23.5...
# 13142          0  None  POLYGON ((-46.59599 -23.48710, -46.59523 -23.4...
# 13151          0  None  POLYGON ((-46.55967 -23.59725, -46.55962 -23.5...
# 13200          0  None  POLYGON ((-46.63051 -23.53272, -46.63017 -23.5...
# 13325          0  None  POLYGON ((-46.71429 -23.56698, -46.71420 -23.5...
# 13394          0  None  POLYGON ((-46.63799 -23.68018, -46.63746 -23.6...
# 13632          0  None  POLYGON ((-46.63719 -23.68499, -46.63706 -23.6...
# 13702          0  None  POLYGON ((-46.66563 -23.53705, -46.66560 -23.5...
# 14048          0  None  POLYGON ((-46.69712 -23.48646, -46.69706 -23.4...
# 14110          0  None  POLYGON ((-46.45654 -23.53898, -46.45652 -23.5...
# 14131          0  None  POLYGON ((-46.59483 -23.54068, -46.59483 -23.5...
# 14208          0  None  POLYGON ((-46.60128 -23.50700, -46.60123 -23.5...
# 14210          0  None  POLYGON ((-46.61294 -23.50328, -46.61291 -23.5...
# 14252          0  None  POLYGON ((-46.60967 -23.49491, -46.60963 -23.4...
# 14267          0  None  POLYGON ((-46.59604 -23.51889, -46.59589 -23.5...
# 14390          0  None  POLYGON ((-46.58082 -23.51871, -46.58062 -23.5...
# 14967          0  None  POLYGON ((-46.61568 -23.50302, -46.61563 -23.5...
# 15062          0  None  POLYGON ((-46.75069 -23.46517, -46.75059 -23.4...
# 15067          0  None  POLYGON ((-46.74445 -23.51908, -46.74443 -23.5...
# 15255          0  None  POLYGON ((-46.59055 -23.48330, -46.59053 -23.4...
# 15339          0  None  POLYGON ((-46.73404 -23.66937, -46.73394 -23.6...
# 15784          0  None  POLYGON ((-46.60979 -23.57970, -46.60974 -23.5...
# 15818          0  None  POLYGON ((-46.60455 -23.63072, -46.60450 -23.6...
# 15822          0  None  POLYGON ((-46.65982 -23.67371, -46.65978 -23.6...
# 15899          0  None  POLYGON ((-46.78705 -23.43568, -46.78682 -23.4...
# 16014          0  None  POLYGON ((-46.69798 -23.56359, -46.69797 -23.5...
# 16018          0  None  POLYGON ((-46.69742 -23.56344, -46.69742 -23.5...
# 16100          0  None  POLYGON ((-46.59438 -23.64566, -46.59435 -23.6...
# 16235          0  None  POLYGON ((-46.68157 -23.65361, -46.68133 -23.6...
# 16315          0  None  POLYGON ((-46.61720 -23.54182, -46.61717 -23.5...
# 16368          0  None  POLYGON ((-46.69448 -23.50203, -46.69446 -23.5...
# 16382          0  None  POLYGON ((-46.70057 -23.49886, -46.70046 -23.4...
# 16388          0  None  POLYGON ((-46.69815 -23.49440, -46.69772 -23.4...
# 16561          0  None  POLYGON ((-46.75717 -23.53868, -46.75673 -23.5...
# 16692          0  None  POLYGON ((-46.62717 -23.53226, -46.62717 -23.5...
# 16745          0  None  POLYGON ((-46.57418 -23.54547, -46.57411 -23.5...
# 16787          0  None  POLYGON ((-46.66729 -23.47406, -46.66728 -23.4...
# 16828          0  None  POLYGON ((-46.58695 -23.51507, -46.58689 -23.5...
# 16834          0  None  POLYGON ((-46.60217 -23.52850, -46.60216 -23.5...
# 16864          0  None  POLYGON ((-46.67833 -23.49406, -46.67778 -23.4...
# 16865          0  None  POLYGON ((-46.67795 -23.49404, -46.67782 -23.4...
# 17056          0  None  POLYGON ((-46.61824 -23.48712, -46.61807 -23.4...
# 17071          0  None  POLYGON ((-46.61794 -23.52269, -46.61792 -23.5...
# 17076          0  None  POLYGON ((-46.62912 -23.53175, -46.62903 -23.5...
# 17077          0  None  POLYGON ((-46.62963 -23.53161, -46.62961 -23.5...
# 17081          0  None  POLYGON ((-46.62893 -23.53277, -46.62891 -23.5...
# 17087          0  None  POLYGON ((-46.63469 -23.53182, -46.63466 -23.5...
# 17097          0  None  POLYGON ((-46.55815 -23.57329, -46.55802 -23.5...
# 17136          0  None  POLYGON ((-46.77021 -23.68415, -46.77013 -23.6...
# 17194          0  None  POLYGON ((-46.62356 -23.61759, -46.62350 -23.6...
# 17208          0  None  POLYGON ((-46.67963 -23.46317, -46.67887 -23.4...
# 17209          0  None  POLYGON ((-46.67931 -23.46343, -46.67873 -23.4...
# 17210          0  None  POLYGON ((-46.67907 -23.46338, -46.67897 -23.4...
# 17285          0  None  POLYGON ((-46.58504 -23.53499, -46.58502 -23.5...
# 17297          0  None  POLYGON ((-46.64936 -23.50062, -46.64927 -23.5...
# 17424          0  None  POLYGON ((-46.62118 -23.56265, -46.62115 -23.5...
# 17559          0  None  POLYGON ((-46.70578 -23.50563, -46.70529 -23.5...
# 17581          0  None  POLYGON ((-46.73273 -23.52355, -46.73234 -23.5...
# 17805          0  None  POLYGON ((-46.69526 -23.52930, -46.69526 -23.5...
# 17806          0  None  POLYGON ((-46.69545 -23.52998, -46.69545 -23.5...
# 17888          0  None  POLYGON ((-46.60231 -23.61764, -46.60223 -23.6...
# 17889          0  None  POLYGON ((-46.60241 -23.62285, -46.60194 -23.6...
# 18164          0  None  POLYGON ((-46.58493 -23.56925, -46.58488 -23.5...
# 18195          0  None  POLYGON ((-46.59194 -23.57063, -46.59186 -23.5...
# 18382          0  None  POLYGON ((-46.64052 -23.46683, -46.64048 -23.4...
# 18429          0  None  POLYGON ((-46.59917 -23.54730, -46.59913 -23.5...
# 18557          0  None  POLYGON ((-46.59408 -23.54848, -46.59404 -23.5...
# 18616          0  None  POLYGON ((-46.62117 -23.47844, -46.62110 -23.4...
# 19153          0  None  POLYGON ((-46.64450 -23.52318, -46.64449 -23.5...
# 19181          0  None  POLYGON ((-46.55472 -23.52929, -46.55442 -23.5...
# 19182          0  None  POLYGON ((-46.55506 -23.52878, -46.55479 -23.5...
# 19240          0  None  POLYGON ((-46.44154 -23.49647, -46.44147 -23.4...
# 19241          0  None  POLYGON ((-46.44169 -23.49678, -46.44164 -23.4...
# 19269          0  None  POLYGON ((-46.70589 -23.50561, -46.70521 -23.5...
# 19279          0  None  POLYGON ((-46.51788 -23.57980, -46.51781 -23.5...
# 19280          0  None  POLYGON ((-46.51781 -23.57958, -46.51759 -23.5...
# 19299          0  None  POLYGON ((-46.63550 -23.53852, -46.63538 -23.5...
# 19341          0  None  POLYGON ((-46.72558 -23.48215, -46.72518 -23.4...
# 19397          0  None  POLYGON ((-46.48144 -23.54383, -46.48086 -23.5...
# 19697          0  None  POLYGON ((-46.52680 -23.53675, -46.52677 -23.5...
# 19698          0  None  POLYGON ((-46.52671 -23.53719, -46.52649 -23.5...
# 19775          0  None  POLYGON ((-46.64957 -23.53690, -46.64906 -23.5...
# 19782          0  None  POLYGON ((-46.47573 -23.52404, -46.47552 -23.5...
# 19787          0  None  POLYGON ((-46.47670 -23.51730, -46.47639 -23.5...
# 19821          0  None  POLYGON ((-46.51935 -23.52301, -46.51934 -23.5...
# 19844          0  None  POLYGON ((-46.62396 -23.51383, -46.62394 -23.5...
# 19884          0  None  POLYGON ((-46.63747 -23.52415, -46.63731 -23.5...
# 19897          0  None  POLYGON ((-46.71429 -23.56698, -46.71328 -23.5...
# 20382          0  None  POLYGON ((-46.65061 -23.55073, -46.64988 -23.5...
# 20675          0  None  POLYGON ((-46.54560 -23.56227, -46.54527 -23.5...
# 20682          0  None  POLYGON ((-46.72038 -23.50269, -46.72018 -23.5...
# 20699          0  None  POLYGON ((-46.69815 -23.49440, -46.69772 -23.4...
# 20751          0  None  POLYGON ((-46.64958 -23.50049, -46.64944 -23.5...
# 20800          0  None  POLYGON ((-46.53549 -23.59993, -46.53529 -23.5...
# 20852          0  None  POLYGON ((-46.63481 -23.68366, -46.63472 -23.6...
# 20889          0  None  POLYGON ((-46.66974 -23.65671, -46.66967 -23.6...
# 20890          0  None  POLYGON ((-46.66974 -23.65671, -46.66964 -23.6...
# 20891          0  None  POLYGON ((-46.66954 -23.65637, -46.66950 -23.6...
# 20941          0  None  POLYGON ((-46.62396 -23.56810, -46.62386 -23.5...
# 21057          0  None  POLYGON ((-46.48860 -23.61296, -46.48853 -23.6...
# 21152          0  None  POLYGON ((-46.63332 -23.54748, -46.63328 -23.5...
# 21207          0  None  POLYGON ((-46.47119 -23.60594, -46.47114 -23.6...

# %% [markdown]
# # Funções de Estações

# %%
## Prepara o dataframe de estações para as outras análises
## Retorna o dataframe tratado
def tratar_df_estacoes(df_estacoes):
    ## Cria uma geometria "Point"
    df_estacoes = gpd.GeoDataFrame(df_estacoes, geometry = gpd.points_from_xy(df_estacoes['lon'], df_estacoes['lat']))
    ## Define crs
    df_estacoes.set_crs("EPSG:4326", inplace = True)
    return df_estacoes

## Cria circles (geometry Polygon) em volta de cada estação (geometry Point)
## Retorna o dataframe com a geometria "circles"
def criar_circulos_estacao(data, radius_km):
    circles = []
    for _, row in data.iterrows():
        circle_points = []
        center = (row['lat'], row['lon'])
        ## Dizemos que é aproximadamente um círculo, pois é um polígono regular com 360 vértices
        for angle in range(0,360, 1): 
            destination = geopy.distance.distance(kilometers = radius_km).destination(center, angle)
            circle_points.append(Point(destination.longitude, destination.latitude))
        circle = gpd.GeoSeries(circle_points).unary_union.convex_hull
        circles.append(circle)
    data.rename(columns = {'geometry':'point'}, inplace = True)
    circles_gdf = gpd.GeoDataFrame(data, geometry = circles)
    circles_gdf.rename(columns = {'geometry':'circle'}, inplace = True)
    return circles_gdf

## Adiciona os círculos no mapa, usa como base a função "criar_circulos_estacao"
## Retorna o Mapa com os círculos (geometry polygon) e pontos (geometry point) adicionados
def adicionar_estacoes_com_circulos_mapa(mapa, df_estacoes, radius_km):
    ## Definição dos layers para controle do usuário por camadas
    layer_estacoes =  folium.FeatureGroup(name = "Estações")
    layer_circulos_estacoes = folium.FeatureGroup(name = f"Redondezas {radius_km} km") 
    ## Se o df_estacoes já tem os circles, não precisa criá-los
    if "circle" not in df_estacoes:
        data = criar_circulos_estacao(df_estacoes, radius_km)
    else:
        data = df_estacoes.copy()
    ## Define "circle" como geometria a ser usada, pois há mais de uma em uso
    data.set_geometry("circle", inplace = True)
    ## Adiciona Circlemarkers ao layer
    for _, row in data.iterrows():
        folium.CircleMarker(
                    location=[row['lat'],row['lon']],
                    color = "blue",
                    radius= 5,
                    tooltip= row['name'],
                    fill=True,
                    fill_opacity=1,
                    fill_color="blue",
                ).add_to(layer_estacoes)
    ## Adiciona os Circles ao layer
    for _, row in data.iterrows():
        folium.GeoJson(
            row['circle'].__geo_interface__, 
            tooltip = row['name'],
            style_function=lambda x:{'fillColor': 'gray', 'color': 'gray', 'fillOpacity': 0.0},
        ).add_to(layer_circulos_estacoes)
        layer_estacoes.add_to(mapa)
        layer_circulos_estacoes.add_to(mapa)
        folium.LayerControl().add_to(mapa)
    return mapa

# %% [markdown]
# # Funções de Mapa

# %%
## Define cores para mapas
def get_color(valor):
    if valor == 1:
        return "yellow"
    elif valor == 2:
        return "orange"
    elif valor == 3:
        return "red"
    elif valor == 4:
        return "darkred"
    elif valor == 5:
        return "blue"
    elif valor == 6:
        return "darkblue"
    elif valor == 7:
        return "purple"
    elif valor == 8:
        return "pink"
    elif valor == 9:
        return "green"
    elif valor == 10:
        return "darkgreen"
    elif valor == 11:
        return "lightblue"
    elif valor == 12:
        return "cyan"
    elif valor == 13:
        return "brown"
    elif valor == 14:
        return "gray"
    elif valor == 15:
        return "black"
    elif valor == 16:
        return "lightgray"
    elif valor == 17:
        return "white"
    else:
        return "black"  # Valor inválido

## Cria um mapa centrado em São Paulo
def criar_mapa_sp():
    mapa_sp = folium.Map(location = [-23.550520, -46.633308], zoom_start = 12)
    return mapa_sp

## Plota Circlemarkers de 1 cor, dado 1 df com Lat e Lon
def plot_circlemarkers_one_color(data, color, radius, name, pontuacao, layer):
    for _, row in data.iterrows():
        folium.CircleMarker(
                location = [row['lat'], row['lon']],
                color = color, 
                radius = radius,
                tooltip = row[name] + " " + str(row[pontuacao]), 
                popup = row[name] + " " + str(row[pontuacao]), 
                fill = True,
                fill_opacity = 1,
                fill_color = color,
        ).add_to(layer)

## Plota Circlemarkers de várias cores, dado 1 df com Lat e Lon e um Colormap branca
def plot_circlemarkers_multi_color(data, radius, name, pontuacao, layer, colormap):
    for _, row in data.iterrows():
        folium.CircleMarker(
                location = [row['lat'], row['lon']],
                color = colormap(row[pontuacao]), 
                radius = radius,
                tooltip = row[name] + " " + str(row[pontuacao]), 
                popup =  row[name] + " " + str(row[pontuacao]), 
                fill = True,
                fill_opacity = 1,
                fill_color = colormap(row[pontuacao]),
        ).add_to(layer)

# %% [markdown]
# ## Funções de Outliers

# %%
## Plota os Circlemarkers outliers dado um out_lower, out_upper e non_outliers, separados pela função "identificar_outliers"
def plot_circlemarkers_outliers(out_lower, out_upper, non_outliers, color_lower, color_upper, radius, 
                                name, pontuacao, layer, colormap):
    plot_circlemarkers_one_color(out_lower, color_lower, radius, name, pontuacao, layer)
    plot_circlemarkers_one_color(out_upper, color_upper, radius, name, pontuacao, layer)
    plot_circlemarkers_multi_color(non_outliers, radius, name, pontuacao, layer, colormap)

def identificar_outliers(df, coluna):
    """
    Identifica outliers em uma coluna de um DataFrame usando o método IQR.

    Parâmetros:
        df (pd.DataFrame): DataFrame contendo os dados.
        coluna (str): Nome da coluna para identificar os outliers.

    Retorna:
        outliers_lower (pd.DataFrame): DataFrame contendo os outliers inferiores.
        outliers_upper (pd.DataFrame): DataFrame contendo os outliers superiores.
        non_outliers (pd.DataFrame): DataFrame contendo os dados não-outliers.
    """
    Q1 = df[coluna].quantile(0.25) 
    Q3 = df[coluna].quantile(0.75)
    IQR = Q3 - Q1
    lowerbound = Q1 - 1.5 * IQR
    upperbound = Q3 + 1.5 * IQR

    outliers_lower = df[df[coluna] < lowerbound]
    outliers_upper = df[df[coluna] > upperbound]
    non_outliers = df[(df[coluna] >= lowerbound) & (df[coluna] <= upperbound)]

    return outliers_lower, outliers_upper, non_outliers

# %% [markdown]
# # Funções de Uso do Solo

# %%
## Prepara o dataframe de ocorrencias para as outras análises
## Retorna o dataframe tratado
def tratar_df_pois(df_pois):
    pois = df_pois.copy()
    pois = pois.rename(columns={'name':'poi_name'})
    pois = pois.to_crs("EPSG:4326")
    return pois
    
def analise_pois(df_pois, df_estacoes, radius_km, pois_selecionados):
    mapa = criar_mapa_sp()
    df_estacoes_circulo = criar_circulos_estacao(df_estacoes, radius_km)
    df_estacoes_circulo.set_geometry("circle", inplace=True)  

    df_estacoes_circulo.set_crs("EPSG:4326", inplace = True)
    ## Quais Pois Considerar?
    df_pois_filtrado = df_pois[df_pois['fclass'].isin(pois_selecionados)]
    
    cruzamentos =  gpd.sjoin(df_estacoes_circulo, df_pois_filtrado, how="inner", predicate="intersects")
    
    cruzamentos = cruzamentos.merge(
        df_pois[["osm_id", "geometry"]],  # Apenas as colunas relevantes
        on="osm_id",  # A coluna para equivalência
        how="left"  # Tipo de junção (left mantém todos os dados de cruzamentos)
    )
    ocorrencias_necessarias_para_plot = cruzamentos.copy()
  
    layer_estacoes = folium.FeatureGroup(name = "Estações")
    layer_circulos_estacoes = folium.FeatureGroup(name = f"Redondezas {radius_km} km") 

    ## Não vou plotar pois, melhor não, tem mts
    # ## Plot do uso do solo
    # layers_dict = {}
    # for place in pois_selecionados:
    #     ocorrencia_por_plot = ocorrencias_necessarias_para_plot[ocorrencias_necessarias_para_plot['fclass'] == place]
    #     layer_pois = folium.FeatureGroup(
    #     name=str(ocorrencias_necessarias_para_plot['pois_selecionados']
    #          [ocorrencias_necessarias_para_plot['fclass'] == place].values[0]),
    #     overlay = True) 
    #     layers_dict[place] = layer_pois
    #     for _, row in ocorrencia_por_plot.iterrows():
    #         cor = get_color(row['fclass'])
    #         geo_json = row['geometry'].__geo_interface__
    #         folium.GeoJson(
    #             geo_json, 
    #             tooltip = str(row['Name']) + " Classe " + str(row['pois_selecionados']),
    #             style_function = lambda x, color = cor:{'fillColor' : color , 'color' : color, 'weight' : 1}
    #         ).add_to(layers_dict[place])
    #     layers_dict[place].add_to(mapa)
        # layers_dict[place].control = False
    # folium.LayerControl(collapsed=False).add_to(mapa)
    # return mapa

    cruzamentos = cruzamentos.groupby('name', as_index = False)['fclass'].count()
    cruzamentos= pd.merge(df_estacoes_circulo, cruzamentos, on = 'name',  how = 'left').fillna(0)
    # return cruzamentos
    # return cruzamentos.isnull().sum()

    # scaler = MinMaxScaler()
    # cruzamentos['fclass'] = scaler.fit_transform(cruzamentos[['fclass']])
    out_lower, out_upper, non_outliers = identificar_outliers(cruzamentos, "fclass")
    colormap = cm.linear.plasma.scale(non_outliers['fclass'].min(), 
                                      non_outliers['fclass'].max())
    colormap.add_to(mapa)
    
    plot_circlemarkers_outliers(out_lower, out_upper, non_outliers, "black", "green", 5, 
                                "name", "fclass", layer_estacoes, colormap)  

    ## Plota círculos em volta das estações
    for _, row in df_estacoes_circulo.iterrows():    
        folium.GeoJson(
            row['circle'].__geo_interface__, 
            tooltip = row['name'],
            style_function=lambda x:{'fillColor': 'gray', 'color': 'gray', 'fillOpacity': 0.0},
        ).add_to(layer_circulos_estacoes)
        
    # layer_pois.add_to(mapa)
    layer_estacoes.add_to(mapa)
    layer_circulos_estacoes.add_to(mapa)
    folium.LayerControl().add_to(mapa)
    return mapa


def roda_analise_pois(geodata, df_estacoes):
    im = interact_manual(
        lambda pois_selecionados, radius_km: analise_pois(geodata,df_estacoes, radius_km, pois_selecionados) ,# Passa df_fixo sem interação
        pois_selecionados=widgets.SelectMultiple(options=[classe for classe in geodata['fclass'].unique()]),
        radius_km = widgets.FloatSlider(min=0, max=2, value=0.5),
    )
    im.widget.children[0].description = 'Quais Pois?'
    im.widget.children[1].description = 'Raio em KM'

# %%
df_pois_all_geometries = pd.concat([pois_points, pois_poligonos, pois_linestrings], ignore_index=True)

df_pois = tratar_df_pois(pois_points)
df_estacoes = tratar_df_estacoes(estacoes)

# %%
roda_analise_pois(df_pois, df_estacoes)
# Out:
# interactive(children=(SelectMultiple(description='pois_selecionados', options=('attraction', 'fast_food', 'mal…

# %%
estacoes = pd.read_parquet("estacoes_reestruturadas.parquet")

# %%
# pois_points
# df_estacoes

# %%
df_pois = tratar_df_pois(pois)
df_estacoes = tratar_df_estacoes(estacoes)

# %%
roda_analise_pois(pois_points, df_estacoes)
# Out:
# interactive(children=(Dropdown(description='pois_selecionados', options=('attraction', 'fast_food', 'mall', 'c…

# %%
analise_pois(df_pois, df_estacoes, 1, )

# %%
df_pois.columns

# %%
df_pois.head()

# %%
df_pois['fclass'].value_counts()

# %%
# df_pois['uso_pred_60'].value_counts()
df_pois.shape
